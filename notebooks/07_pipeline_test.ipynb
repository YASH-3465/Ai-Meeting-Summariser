# %%
import sys
sys.path.append("..")

from src.pipeline.meeting_pipeline import MeetingPipeline

pipeline = MeetingPipeline()
# Out:
# Device set to use cpu

# %%
result = pipeline.run("../data/raw/sample_meeting.wav",notify=True,translate=True)

print("\nSUMMARY:")
print(result["summary"])

print("\nACTIONS:")
if not result["actions"]:
    print("No action items identified.")
else:
    for i, action in enumerate(result["actions"], 1):
        deadline = action["deadline"] or "No deadline"
        print(f"{i}. {action['action']} (Deadline: {deadline})")
# Out:
# C:\Users\yashw\Meeting Summariser\venv\Lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# SUMMARY:
# Below is a concise summary of the meeting discussion: Key factual highlights: coming to computer science engineering, we had 240 students appear for the examinations. out of these, 212 students passed and 28 students failed, which gives an overall pass percentage of around 88 . in the electronics and communication engineering department, 180 students appeared for the exams. among them, 150 students passed and 30 students failed, resulting in a pass percentage of approximately 83 . next, in electrical and electronics engineering, 120 students appeared for the examinations. out of these, 102 students passed and 18 students failed, giving a pass percentage of about 85 .
#
# ...
