# %%
import sys
sys.path.append("..")

from src.pipeline.meeting_pipeline import MeetingPipeline

pipeline = MeetingPipeline()
# Out:
# Device set to use cpu

# %%
result = pipeline.run("../data/raw/sample_meeting.wav",notify=True,translate=True)

print("\nSUMMARY:")
print(result["summary"])

print("\nACTIONS:")
if not result["actions"]:
    print("No action items identified.")
else:
    for i, action in enumerate(result["actions"], 1):
        deadline = action["deadline"] or "No deadline"
        print(f"{i}. {action['action']} (Deadline: {deadline})")
# Out:
# C:\Users\yashw\Meeting Summariser\venv\Lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# SUMMARY:
# Below is a concise summary of the meeting discussion: The user administration system is fully implemented in the view of the back end team. The most important apis for registration and user profiles have been completed. Internal tests have given positive feedback and only small adjustments are still open. All teams should also reach a short progress report by april 12, 2026.
#
# ACTIONS:
# 1. all teams should also reach a short progress report by april 12, 2026. (Deadline: april 12)
